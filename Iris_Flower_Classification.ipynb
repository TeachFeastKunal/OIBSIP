# %% [markdown]
# <a href="https://colab.research.google.com/github/TeachFeastKunal/OIBSIP/blob/main/Iris_Flower_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata
import kagglehub
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import  classification_report , mean_absolute_error , mean_squared_error , confusion_matrix

# %%
import os
os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
os.environ['KAGGLE_KEY'] = userdata.get('KAGGLE_KEY')

# %%
iris_Data = kagglehub.dataset_download("saurabh00007/iriscsv")
OIBSIP_path = '/content/drive/MyDrive/OIB_SIP'
# Out:
# Using Colab cache for faster access to the 'iriscsv' dataset.

# %%
df = pd.read_csv('/kaggle/input/iriscsv/Iris.csv')
df.dropna(inplace=True)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Visualization

# %%
sns.pairplot(df.drop('Id' , axis = 1) , hue = 'Species' , palette= 'YlGn_r')

# %% [markdown]
# ## Modelling

# %%
x = df.drop(['Id' , 'Species'] , axis = 1)
y = df['Species']

x_train , x_test , y_train , y_test = train_test_split(x , y , test_size= 0.3 , random_state= 10)

model = SVC(kernel = 'linear')
model.fit(x_train , y_train)

y_pred = model.predict(x_test)

# %% [markdown]
# ## Model Report

# %%
print(classification_report(y_test , y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       1.00      1.00      1.00        17
#  Iris-virginica       1.00      1.00      1.00        14
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
